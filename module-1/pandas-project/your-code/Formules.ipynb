# %%
import pandas as pd

# %%
data = pd.read_csv('GSAF5.csv', encoding = 'latin')
data.head(5)
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#     Species        Investigator or Source                        pdf  \
# ...

# %%
#récap des principales infos sur un dataframe (moyenne, max, min...)
data.describe(include='all').transpose

# %%
#affichage des fréquences en dégressif
    from collections import Counter
Counter(data['Country']).most_common()

#nb lignes d'un dataframe
data[filtformula == False].shape[0]
#nb colonnes d'un dataframe
data[filtformula == False].shape[1]
# Out:
#   File "<ipython-input-3-decbd5ee62d9>", line 2
#     from collections import Counter
#     ^
# IndentationError: unexpected indent

# %%
# suppression des espaces en trop (y compris en milieu de chaine)

def supprespace(x):
    if type(x) is str:
        return re.sub(' +', ' ',(x.strip()))
    return x

# %%
# suppression des éventuelles lignes redondantes
data.drop_duplicates()
# Out:
#        Case Number                                               Date  Year  \
# 0     2016.09.18.c                                          18-Sep-16  2016
# 1     2016.09.18.b                                          18-Sep-16  2016
# 2     2016.09.18.a                                          18-Sep-16  2016
# 3       2016.09.17                                          17-Sep-16  2016
# 4       2016.09.15                                          16-Sep-16  2016
# 5     2016.09.15.R                                          15-Sep-16  2016
# 6       2016.09.11                                          11-Sep-16  2016
# 7       2016.09.07                                          07-Sep-16  2016
# 8       2016.09.06                                          06-Sep-16  2016
# 9     2016.09.05.b                                          05-Sep-16  2016
# 10    2016.09.05.a                                          05-Sep-16  2016
# ...

# %%
#checke le contenu des colonnes presque vides
data[data['Unnamed: 22'].fillna(0) != 0]
# Out:
#      Case Number       Date  Year        Type Country        Area  \
# 1247  2006.06.18  18-Jun-06  2006  Unprovoked  BRAZIL  Pernambuco
#
#                             Location       Activity                     Name  \
# 1247  Punta Del Chifre Beach, Olinda  Body boarding  Humberto Pessoa Batista
#
#      Sex   ... Species  Investigator or Source                     pdf  \
# 1247    M  ...      NaN     globalsurfnews.com  2006.06.18-Batista.pdf
#
#                                            href formula  \
# 1247  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href Case Number.1  \
# 1247  http://sharkattackfile.net/spreadsheets/pdf_di...    2006.06.18
#
#      Case Number.2 original order   Unnamed: 22 Unnamed: 23
# 1247    2006.06.18           4746  stopped here         NaN
#
# [1 rows x 24 columns]

# %%
#vérifier les différences entre 2 colonnes
data[data['href formula'].eq(data['href']) == False]
# Out:
#        Case Number                  Date  Year          Type  \
# 20      2016.07.29             29-Jul-16  2016    Unprovoked
# 27    2016.07.23.a             23-Jul-16  2016    Unprovoked
# 61    2016.05.21.a             21-May-16  2016    Unprovoked
# 107   2015.12.21.a             21-Dec-15  2015    Unprovoked
# 114   2015.11.15.a             15-Nov-15  2015    Unprovoked
# 134   2015.10.05.a             05-Oct-15  2015    Unprovoked
# 180   2015.06.27.a             27-Jun-15  2015    Unprovoked
# 193     2015.06.13             13-Jun-15  2015    Unprovoked
# 232     2015.01.24             24-Jan-15  2015    Unprovoked
# 262     2014.10.19             19-Oct-14  2014          Boat
# 263     2014.10.18             18-Oct-14  2014    Unprovoked
# 264     2014.10.17             17-Oct-14  2014    Unprovoked
# 271   2014.10.03.b             03-Oct-14  2014          Boat
# 272   2014.10.03.a             03-Oct-14  2014          Boat
# ...

# %%
#filtrer selon plusieurs critères + choix des colonnes à afficher dans le résultat
data.loc[(data['Country'] == "REUNION") & (data['Area'] is None), ['Country', 'Area', 'Location']]
data[data['Case Number'] == '2016.09.18.c']
# Out:
#     Case Number       Date  Year        Type Country     Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked     USA  Florida
#
#                            Location Activity  Name Sex   ... Species   \
# 0  New Smyrna Beach, Volusia County  Surfing  male    M  ...      NaN
#
#         Investigator or Source                   pdf  \
# 0  Orlando Sentinel, 9/19/2016  2016.09.18.c-NSB.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.09.18.c
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0  2016.09.18.c           5993         NaN         NaN
#
# [1 rows x 24 columns]

# %%
#apply sur une colonne
data['Date'] = data['Date'].apply(supprespace)
#apply sur l'ensemble du dataframe : applymap agit sur les lignes
data.applymap(supprespace)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-cfd5e8fc8ec0> in <module>
#       1 #apply sur une colonne
# ----> 2 data['Date'] = data['Date'].apply(supprespace)
#       3 #apply sur l'ensemble du dataframe : applymap agit sur les lignes
#       4 data.applymap(supprespace)
#
# NameError: name 'supprespace' is not defined

# %%
#tester si une formule a une action

before = data.loc[values.index, 'href formula'].values

data.loc[values.index, 'href'] = data.loc[values.index, 'href formula']
after = data.loc[values.index, 'href formula'].values

(after==before).any()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c5f88bca9f9b> in <module>
#       1 #tester si une formule a une action
#       2
# ----> 3 before = data.loc[values.index, 'href formula'].values
#       4
#       5 data.loc[values.index, 'href'] = data.loc[values.index, 'href formula']
#
# NameError: name 'values' is not defined

# %%
#champ contient...
cond = df_rss[df_rss['summary'].str.contains("machine learning")]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3c3f30abe11c> in <module>
#       1 #champ contient...
# ----> 2 cond = df_rss[df_rss['summary'].str.contains("machine learning")]
#
# NameError: name 'df_rss' is not defined

# %%
#afficher la valeur complète d'un champ long
for path in paths_df['_links.html']:
    print(path)

# %%
#afficher une ligne
data.iloc[57,:]
