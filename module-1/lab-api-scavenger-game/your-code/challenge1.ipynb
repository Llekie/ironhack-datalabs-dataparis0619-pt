# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
password  = open("D:\\Users\\lleki\\Desktop\\Ironhack\\password_token_git_lab_api.txt").read()

# %%
listeforks = requests.get("https://api.github.com/repos/mayadesp/ironhack-datalabs-dataparis0619-pt/forks", headers={"Authorization": 'token ' + password})

# %%
listeforks.content
# Out:
# b'[{"id":190438538,"node_id":"MDEwOlJlcG9zaXRvcnkxOTA0Mzg1Mzg=","name":"ironhack-datalabs-dataparis0619-pt","full_name":"orianegsx/ironhack-datalabs-dataparis0619-pt","private":false,"owner":{"login":"orianegsx","id":7051636,"node_id":"MDQ6VXNlcjcwNTE2MzY=","avatar_url":"https://avatars1.githubusercontent.com/u/7051636?v=4","gravatar_id":"","url":"https://api.github.com/users/orianegsx","html_url":"https://github.com/orianegsx","followers_url":"https://api.github.com/users/orianegsx/followers","following_url":"https://api.github.com/users/orianegsx/following{/other_user}","gists_url":"https://api.github.com/users/orianegsx/gists{/gist_id}","starred_url":"https://api.github.com/users/orianegsx/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/orianegsx/subscriptions","organizations_url":"https://api.github.com/users/orianegsx/orgs","repos_url":"https://api.github.com/users/orianegsx/repos","events_url":"https://api.github.com/users/orianegsx/events{/privacy}","
# ...

# %%
jsforks = listeforks.json()

# %%
forks_df = json_normalize(jsforks)

# %%
forks_df.columns
# Out:
# Index(['archive_url', 'archived', 'assignees_url', 'blobs_url', 'branches_url',
#        'clone_url', 'collaborators_url', 'comments_url', 'commits_url',
#        'compare_url', 'contents_url', 'contributors_url', 'created_at',
#        'default_branch', 'deployments_url', 'description', 'disabled',
#        'downloads_url', 'events_url', 'fork', 'forks', 'forks_count',
#        'forks_url', 'full_name', 'git_commits_url', 'git_refs_url',
#        'git_tags_url', 'git_url', 'has_downloads', 'has_issues', 'has_pages',
#        'has_projects', 'has_wiki', 'homepage', 'hooks_url', 'html_url', 'id',
#        'issue_comment_url', 'issue_events_url', 'issues_url', 'keys_url',
#        'labels_url', 'language', 'languages_url', 'license.key',
#        'license.name', 'license.node_id', 'license.spdx_id', 'license.url',
#        'merges_url', 'milestones_url', 'mirror_url', 'name', 'node_id',
#        'notifications_url', 'open_issues', 'open_issues_count',
# ...

# %%
forks_df['language'].unique()
# Out:
# array(['Jupyter Notebook'], dtype=object)
